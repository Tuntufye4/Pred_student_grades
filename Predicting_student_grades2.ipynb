# failures    0.063726 -0.354718 -0.355896 -0.360415
# famrel     -0.044354  0.022168 -0.018281  0.051363
# freetime   -0.058078  0.012613 -0.013777  0.011307
# goout       0.044302 -0.149104 -0.162250 -0.132791
# Dalc        0.111908 -0.094159 -0.064120 -0.054660
# Walc        0.136291 -0.126179 -0.084927 -0.051939
# health     -0.029937 -0.073172 -0.097720 -0.061335
# absences    1.000000 -0.031003 -0.031777  0.034247
# G1         -0.031003  1.000000  0.852118  0.801468
# G2         -0.031777  0.852118  1.000000  0.904868
# G3          0.034247  0.801468  0.904868  1.000000

# %%
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
predict = "G3"
x = np.array(data.drop([predict], 1))
y = np.array(data[predict])
# Out:
# C:\Users\Tuntu\AppData\Local\Temp\ipykernel_16196\791956819.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = np.array(data.drop([predict], 1))

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %%
linear_regression = LinearRegression()
lr = linear_regression.fit(xtrain, ytrain)

# %%
# save the model to disk
filename = 'finalized_model.sav'
joblib.dump(lr, filename)
# Out:
# ['finalized_model.sav']

# %%
loaded_model = joblib.load(filename)
accuracy = loaded_model.score(xtest, ytest)

print(accuracy)
# Out:
# 0.7660415537613249

# %%
print('Coefficient: \n', loaded_model.coef_)
print('Intercept: \n', loaded_model.intercept_)
# Out:
# Coefficient:
#  [ 0.1421959   0.9679932  -0.13591151 -0.2015248   0.05035651]
# Intercept:
#  -1.322483038455232

# %%
predictions = loaded_model.predict(xtest)

for x in range(len(predictions)):
    print(predictions[x], xtest[x], ytest[x])
# Out:
# 16.269432617377703 [16 16  2  0  2] 16
# 8.40866123672949 [ 6  9  1  2 14] 8
# 10.748803151714721 [11 11  4  0  8] 10
# 9.37167347000511 [10 10  3  0  0] 9
# 8.456626015828666 [8 9 2 0 4] 10
# 12.654473505049161 [11 13  2  0  2] 14
# 11.95302609274619 [15 12  2  1  0] 12
# 14.020140319458458 [15 14  4  0  4] 14
# 18.827148373974488 [18 18  1  0  6] 18
# 15.1177606342645 [14 15  2  0  4] 15
# 5.048883798777643 [8 6 2 2 2] 5
# 6.106620696394674 [7 7 4 0 4] 6
# 10.138385246203372 [ 7 10  2  1 25] 11
# 14.256764848395218 [15 14  3  0  6] 14
# 4.300261406648738 [6 5 2 0 4] 6
# 8.74101781893929 [10  9  2  0  4] 9
# 13.799861094029069 [12 14  1  0  0] 15
# 8.456626015828666 [8 9 2 0 4] 10
# 15.064814886923617 [16 15  3  0  0] 15
# 11.509085916069255 [10 12  3  0  4] 12
# 8.397395874354485 [9 9 2 0 0] 10
# 15.159243514305064 [15 15  2  0  2] 14
# 17.93354333878145 [17 17  2  0 13] 17
# 12.83815228664504 [13 13  2  0  0] 13
# 5.975394120254403 [7 7 2 2 4] 9
# 7.287206771281847 [8 8 2 0 0] 0
# 10.860683003569823 [12 11  2  0  2] 12
# 14.305018862915254 [11 12  2  0 54] 11
# 13.942056995584382 [13 14  1  0  0] 13
# 10.902165883610389 [13 11  2  0  0] 10
# -0.4269163330418212 [12  0  3  2  0] 0
# 15.058530492790318 [15 15  2  0  0] 15
# 5.714639183288074 [8 7 2 3 0] 0
# 9.235761962583094 [10 10  4  0  0] 10
# 9.286065806553593 [11  9  2  0 12] 9
# 10.191186375833825 [ 8 11  2  0  0] 11
# 16.269432617377703 [16 16  2  0  2] 17
# 4.033222075549109 [6 5 1 1 0] 0
# 12.835510383274654 [16 12  1  0  8] 13
# 8.267768761065769 [10  9  4  0  0] 0
# 4.939738021644486 [ 6  5  1  0 14] 5
# 8.033582049462986 [ 9  8  2  1 16] 7
# 19.996567618521308 [18 19  1  0 10] 19
# 17.007085684091567 [17 17  4  0  0] 18
# 11.217360476767396 [ 9  9  2  0 56] 8
# 13.400947535692955 [12 13  2  0 14] 12
# 5.3449359741138975 [7 6 1 0 0] 0
# 12.584076533234626 [11 13  4  0  6] 14
# 10.71848710201451 [11 11  2  0  2] 11
# 3.76139906070508 [6 5 3 1 0] 0
# 16.30463110328497 [16 16  1  0  0] 15
# 18.927861395489234 [18 18  1  0  8] 18
# 11.727963183572403 [12 12  2  0  0] 11
# 13.880533654486653 [12 14  3  0  7] 14
# 7.367826664952556 [ 9  7  2  0 18] 6
# 12.702240779223025 [13 13  3  0  0] 14
# 9.229477568449797 [ 9 10  3  0  0] 0
# 4.9418863831295985 [7 6 1 2 0] 0
# 4.560917591152412 [ 5  5  2  0 12] 5
# 8.009649146358727 [10  8  1  0  6] 11
# 6.041106160787195 [7 7 3 0 0] 8
# 13.996352034064628 [13 13  2  0 23] 13
# 8.195871078862336 [9 9 2 1 0] 0
# 12.316330082712804 [10  9  2  0 75] 9
# 14.981849126842484 [14 15  3  0  4] 16
# 8.391111480221188 [8 9 1 0 0] 8
# 8.59882191738398 [9 9 2 0 4] 10
# 12.089332389590822 [11 12  2  0 10] 13
# 15.017047612749753 [14 15  2  0  2] 15
# 13.28857414195258 [15 13  3  2 14] 13
# 11.014341772425453 [10 11  1  0  8] 10
# 12.086690486220437 [14 11  1  0 18] 13
# -0.3208273334347447 [8 0 1 0 0] 0
# 8.793963566280175 [8 9 1 0 8] 10
# 13.578394589942413 [12 14  3  0  1] 15
# 8.106620924647906 [6 9 1 1 4] 8
# 5.771622210814487 [ 6  6  2  2 22] 4
# 13.94834138971768 [14 14  2  0  0] 14
# 8.699534938898726 [9 9 2 0 6] 10

# %%
print(loaded_model.predict([[5, 6, 2, 0, 6]]))
# Out:
# [5.1125016]
